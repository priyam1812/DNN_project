# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.9.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %%
# !pip install transformers torchvision einops
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch==2.9.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.9.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision) (3.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0->torchvision) (3.0.3)

# %%
! pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from datasets import load_dataset

dataset = load_dataset("daniel3303/StoryReasoning")
print(dataset)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['story_id', 'images', 'frame_count', 'chain_of_thought', 'story'],
#         num_rows: 3552
#     })
#     test: Dataset({
#         features: ['story_id', 'images', 'frame_count', 'chain_of_thought', 'story'],
#         num_rows: 626
#     })
# })

# %%
print("A sample story entry:\n")

sample = dataset["train"][0]
print("Story ID:", sample["story_id"])
print("Frame count:", sample["frame_count"])
print("Images (list of URLs):", sample["images"])
print("Text:", sample["story"])
print("Chain-of-thought:", sample["chain_of_thought"])
# Out:
# A sample story entry:
#
# Story ID: 3920
# Frame count: 17
# Images (list of URLs): [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB01E57A660>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB01C2623C0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4DE50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4DDC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E2A0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E360>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E420>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E4E0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E5A0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E660>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E720>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E7E0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E8A0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4E960>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4EA20>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4EAE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=575x240 at 0x7EB00BF4EBA0>]
# Text: <gdi image1>
# In the sterile environment of a sparse room filled with <gdo obj1>cardboard boxes</gdo>, <gdo obj5>a blue blanket</gdo>, and <gdo bg26>a table</gdo>, <gdo char1>James</gdo> <gda char1>enters</gda> with a neutral look. His face reflects the calm before the storm. <gdo char1>James</gdo> <gda char1>enters</gda> an empty room that holds the remnants of what looks like a hastily abandoned office. The room's <gdl bg1>neutral lighting</gdl> and <gdl bg2>simple, minimalistic architecture</gdl> add to the eerie silence. <gdo char1>James</gdo> <gda char1>looks around</gda> with a sense of purpose, as if searching for something or someone.
# </gdi>
#
# <gdi image2>
# Suddenly, the stillness is shattered by the appearance of <gdo char3>Jack</gdo>. <gdo char3>Jack</gdo> <gda char3>looks around</gda> with an intense, concerned expression. His eyes dart around the room, suggesting he's on high alert. The atmosphere thickens with tension as <gdo char3>Jack</gdo> <gda char3>realizes</gda> he's not alone. The room's <gdl bg3>plain interior</gdl> amplifies the sense of danger, and <gdo char3>Jack</gdo> <gda char3>starts</gda> to feel the weight of an impending threat.
# </gdi>
#
# <gdi image3>
# With a heavy heart, <gdo char1>James</gdo> <gda char1>enters</gda> an elevator, his mind racing with thoughts of what might be waiting for <gdo char1>him</gdo> on the other side. The <gdo obj7>elevator</gdo> seems to move slowly, each second feeling like an eternity. <gdo char1>James</gdo> <gda char1>wonders</gda> if he's made the right decision to come here. The confined space of the elevator adds to the claustrophobic feeling, and <gdo char1>James</gdo> <gda char1>tries</gda> to gather <gdo char1>his</gdo> thoughts in preparation for what lies ahead.
# </gdi>
#
# <gdi image4>
# The elevator doors open, and <gdo char4>Alex</gdo> <gda char4>stands</gdo> in the hallway. <gdo char4>Alex</gdo> <gda char4>looks</gda> alert, as if he's been expecting <gdo char1>James</gdo>. The hallway, with its <gdl bg4>plain modern architecture</gdl>, feels cold and unwelcoming. <gdo char4>Alex</gdo> <gda char4>glances</gda> at <gdo char1>James</gdo>, and for a moment, there's an unspoken tension between <gdo char1 char4>them</gdo>. <gdo char4>Alex</gdo> <gda char4>gestures</gda> for <gdo char1>James</gdo> to follow, leading <gdo char1>him</gdo> deeper into the unknown.
# </gdi>
#
# <gdi image5>
# A blurred figure, <gdo char5>Unidentified</gdo>, <gda char5>appears</gda> in the hallway. The scene is shrouded in mystery, and the atmosphere grows even more tense. <gdo char1>James</gdo> <gda char1>can't make out</gda> who <gdo char5>Unidentified</gdo> <gda char5>is</gda>, but <gdo char1>James</gdo> <gda char1>feels</gda> a chill run down <gdo char1>his</gdo> spine. The presence of <gdo char5>Unidentified</gdo> adds another layer of uncertainty to an already precarious situation.
# </gdi>
#
# <gdi image6>
# The tension reaches a boiling point as <gdo char1>James</gdo> <gda char1>confronts</gda> <gdo char4>Alex</gdo>. <gdo char1>James</gdo> <gda char1>holds a gun</gda>, aiming it at <gdo char4>Alex</gdo> with a steady hand. <gdo char4>Alex</gdo>, in turn, <gda char4>points a gun</gdo> back at <gdo char1>James</gdo>. The hallway turns into a standoff, with both <gdo char1 char4>men</gdo> locked in a deadly stare. The <gdl bg5>wall</gdl> behind <gdo char1 char4>them</gdo> seems to close in, amplifying the intensity of the moment.
# </gdi>
#
# <gdi image7>
# In another room, <gdo char3>Jack</gdo> <gda char3>holds a gun</gda>, aiming it with a look of anger and determination. The room is cluttered with <gdo obj3>cardboard boxes</gdo>, adding to the chaotic atmosphere. <gdo char3>Jack</gdo> <gda char3>feels</gda> a surge of rage, his emotions boiling over. The <gdl bg6>plain, minimalistic architecture</gdl> of the room seems to reflect the turmoil within <gdo char3>Jack</gdo>. The situation is reaching its climax, and the outcome hangs in the balance.
# </gdi>
#
# <gdi image8>
# The confrontation takes a dark turn as <gdo char1>James</gdo> <gda char1>finds himself</gda> with a bloody face, holding <gdo char1>his</gdo> face in distress. The <gdl bg7>interior space</gdl> feels oppressive, and <gdo char1>James</gdo> <gda char1>realizes</gda> the gravity of the situation. The intensity of the moment is palpable, and <gdo char1>James</gdo> <gda char1>feels</gda> the weight of the consequences of <gdo char1>his</gdo> actions. The atmosphere is tense, and the stakes are higher than ever.
# </gdi>
#
# <gdi image9>
# With a sense of urgency, <gdo char1>James</gdo> <gda char1>grabs</gda> <gdo obj9>a cell phone</gdo>, using it to make a call. <gdo char1>James</gdo> <gda char1>knows</gda> that <gdo char1>he</gdo> needs help, and the phone call is <gdo char1>his</gdo> only hope. The <gdl bg8>interior space</gdl> remains tense, and <gdo char1>James</gdo> <gda char1>tries</gda> to stay focused as <gdo char1>he</gdo> <gda char1>communicates</gda> with someone on the other end of the line. The situation is critical, and every second counts.
# </gdi>
#
# <gdi image10>
# The atmosphere shifts as <gdo char1>James</gdo> <gda char1>points</gda> <gdo char1>his</gdo> finger, showing a sense of anger and intensity. <gdo char4>Alex</gdo> stands nearby, the tension between <gdo char1 char4>them</gdo> palpable. The <gdl bg9>interior space</gdl> feels charged with energy, and <gdo char1>James</gdo> <gda char1>conveys</gda> <gdo char1>his</gdo> determination through <gdo char1>his</gdo> gestures. The situation is reaching its peak, and the outcome remains uncertain.
# </gdi>
#
# <gdi image11>
# The room is filled with chaos as <gdo char1>James</gdo> <gda char1>lies motionless</gdo> on the floor, injured and in pain. <gdo obj10>A handbag</gdo> and <gdo obj1>cardboard boxes</gdo> are scattered around, adding to the disarray. The atmosphere is tense, and the scene reflects the aftermath of a violent confrontation. The <gdl bg10>interior space</gdl> feels heavy, and the silence is deafening. The situation has taken a dark turn, and the consequences are all too real.
# </gdi>
#
# <gdi image12>
# The tension escalates as <gdo char1>James</gdo>, <gdo char2>John</gdo>, and <gdo char4>Alex</gdo> <gda char1 char2 char4>find themselves</gda> in a room filled with <gdo obj1>cardboard boxes</gdo> and <gdo obj11 obj12>chairs</gdo>. <gdo char1>James</gdo> <gda char1>points a gun</gda> at <gdo char2>John</gdo>, who is sitting on the floor, injured and motionless. <gdo char4>Alex</gdo> stands nearby, holding a gun in a threatening manner. The atmosphere is tense, and the outcome of the confrontation is uncertain. The <gdl bg11>interior space</gdl> feels charged with danger, and the scene reflects the climax of a dangerous situation.
# </gdi>
#
# <gdi image13>
# The confrontation reaches its peak as <gdo char1>James</gdo> and <gdo char3>Jack</gdo> <gda char1 char3>stand</gda> in a room, both <gda char1 char3>pointing guns</gda> at each other. The tension is palpable, and the outcome hangs in the balance. <gdo char1>James</gdo> <gda char1>looks</gda> angry, and <gdo char3>Jack</gdo> <gda char3>mirrors</gda> <gdo char1>James</gdo>'s intensity. The <gdl bg12>interior space</gdl> feels charged with energy, and the scene reflects the climax of a dangerous situation. The stakes are high, and the outcome is uncertain.
# </gdi>
#
# <gdi image14>
# The tension reaches a boiling point as <gdo char3>Jack</gdo> <gda char3>points a gun</gda> with an angry expression. <gdo char3>Jack</gdo> <gda char3>holds</gda> <gdo obj9>a cell phone</gdo>, adding to the complexity of the situation. The <gdl bg13>interior space</gdl> feels charged with energy, and <gdo char3>Jack</gdo> <gda char3>conveys</gda> <gdo char3>his</gdo> determination through <gdo char3>his</gdo> actions. The outcome is uncertain, and the situation is reaching its climax.
# </gdi>
#
# <gdi image15>
# The confrontation reaches its turning point as <gdo char1>James</gdo> <gda char1>holds a gun</gda>, aiming it with a sense of anger and determination. The <gdl bg14>interior space</gdl> feels tense, and <gdo char1>James</gdo> <gda char1>realizes</gda> the gravity of the situation. The atmosphere is charged with energy, and the stakes are higher than ever. The outcome remains uncertain, and the situation is reaching its climax.
# </gdi>
#
# <gdi image16>
# The tension eases slightly as <gdo char1>James</gdo> <gda char1>enters</gda> an elevator, possibly leaving the scene. <gdo char1>James</gdo> <gda char1>holds an umbrella</gda>, suggesting <gdo char1>he</gdo> <gda char1>is</gda> prepared for any eventuality. The <gdo obj7>elevator</gdo> provides a moment of respite from the chaos, and <gdo char1>James</gdo> <gda char1>contemplates</gda> <gdo char1>his</gdo> next move. The atmosphere remains tense, but there's a glimmer of hope as <gdo char1>James</gdo> <gda char1>seeks</gda> a way out of the situation.
# </gdi>
#
# <gdi image17>
# The scene shifts to a different location as <gdo char1>James</gdo> <gda char1>enters</gda> another elevator. This time, <gdo char1>James</gdo> <gda char1>holds an umbrella</gda>, and the atmosphere feels more somber. The <gdo obj7>elevator</gdo> provides a moment of solitude, and <gdo char1>James</gdo> <gda char1>reflects</gda> on the events that have unfolded. The <gdl bg15>modern elevator interior</gdl> feels confined, but it offers a temporary escape from the chaos. The story reaches its conclusion as <gdo char1>James</gdo> <gda char1>prepares</gda> to leave behind the conflict and uncertainty of the past.
# </gdi>
# Chain-of-thought: ## Image 1
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man with a neutral look | Calm | Enters an empty room | Initiates the setting | 318,48,345,135 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj1 | Cardboard boxes | Storage | None | Sets up the scene | 0,63,449,166 |
# | obj5 | Blue blanket | Bedding | None | Adds detail | 203,135,407,218 |
# | bg26 | Table | Furniture | None | Sets the interior | 119,162,237,238 |
# | bg29 | Counter or table | Furniture | None | Sets the interior | 387,135,477,237 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | A sparse room | Neutral | Unknown | Establishes setting |
# | Lighting | Neutral lighting | Neutral | Unknown | Sets a calm mood |
# | Architecture | Simple, minimalistic architecture | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 2
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char3 | Jack | Man with an intense look | Concerned | Looks around | Introduces a potential threat | 0,0,560,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg30 | Ceiling | Structure | None | Sets the environment | 410,4,571,210 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Unknown | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Plain, no distinctive features | Unknown | Unknown | Adds to the setting |
#
#
# ## Image 3
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man wearing a white shirt | Focused | Enters an elevator | Moves to a different location | 283,29,410,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj7 | Elevator | Transportation | Used by char1 | Moves the character | 0,0,448,239 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | Elevator | Neutral | Unknown | Transition |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Modern elevator interior | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 4
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char4 | Alex | Man in a black jacket | Alert | Inside a structure | Sets up potential conflict | 132,33,358,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg34 | Window | Transparent | None | Provides view | 56,5,200,230 |
# | bg37 | Window | Transparent | None | Provides view | 338,99,417,236 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | Interior with windows | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Plain, modern | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 5
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man with a shaved head | Intense | Holds a gun | Initiates conflict | 190,51,401,239 |
# | char4 | Alex | Man in black jacket | Threatening | Points a gun | Intensifies conflict | 412,25,526,235 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg2 | Wall | Structure | None | Sets the environment | 4,6,157,234 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | A hallway or corridor | Tense | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Tense due to confrontation | Intense | Unknown | Adds to the tension |
#
#
# ## Image 6
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char5 | Unidentified | Blurred person | Unclear | Unknown | Creates mystery | 249,0,574,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg5 | Wall | Structure | None | Sets the environment | 7,4,330,234 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Unknown | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Unclear due to blur | Unknown | Unknown | Adds to the mystery |
#
#
# ## Image 7
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char3 | Jack | Man holding a gun | Angry | Points a gun | Intensifies conflict | 292,27,438,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj3 | Cardboard box | Storage | None | Adds detail | 400,81,517,239 |
# | bg3 | Wall | Structure | None | Sets the environment | 4,6,157,234 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Plain, minimalistic | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 8
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man with a bloody face | Distressed | Holding his face | Shows result of conflict | 0,0,574,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg5 | Wall | Structure | None | Sets the environment | 7,4,330,234 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Unknown | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Intense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 9
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man holding his face | Distressed | Holding his face | Shows result of conflict | 0,0,459,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj9 | Cell phone | Communication | Held by char1 | Adds detail | 0,64,40,162 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Unknown | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Intense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 10
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man in a black jacket | Angry | Pointing | Shows intensity | 127,11,505,238 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | bg5 | Wall | Structure | None | Sets the environment | 7,4,330,234 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Unknown | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Intense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 11
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man lying on the floor | Injured | Motionless | Shows aftermath of conflict | 93,105,448,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj1 | Cardboard boxes | Storage | None | Adds detail | 0,0,574,239 |
# | obj10 | Handbag | Storage | None | Adds detail | 344,188,482,239 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Tense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 12
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man in a black jacket | Angry | Pointing | Shows intensity | 134,109,240,222 |
# | char2 | John | Man sitting on the floor | Injured | Motionless | Shows aftermath of conflict | 283,29,410,239 |
# | char4 | Alex | Man in a black jacket | Threatening | Holds a gun | Intensifies conflict | 276,2,485,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj1 | Cardboard boxes | Storage | None | Adds detail | 299,70,574,239 |
# | obj11 | Chair | Furniture | None | Adds detail | 245,92,318,150 |
# | obj12 | Chair | Furniture | None | Adds detail | 186,40,259,99 |
# | obj9 | Cell phone | Communication | Held by char1 | Adds detail | 0,64,40,162 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Tense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 13
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man in a black jacket | Angry | Pointing | Shows intensity | 0,88,297,239 |
# | char3 | Jack | Man holding a gun | Angry | Points a gun | Intensifies conflict | 292,27,438,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj8 | Door | Structure | None | Sets the environment | 290,56,352,219 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Tense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 14
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char3 | Jack | Man holding a gun | Angry | Points a gun | Intensifies conflict | 236,27,574,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj9 | Cell phone | Communication | Held by char3 | Adds detail | 250,124,297,176 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Plain, minimalistic | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 15
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man holding a gun | Angry | Points a gun | Intensifies conflict | 49,22,574,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj4 | Cardboard box | Storage | None | Adds detail | 338,0,567,129 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Plain, minimalistic | Neutral | Unknown | Adds to the setting |
#
#
# ## Image 16
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man holding a phone | Concerned | Using a phone | Communicating | 0,0,395,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj9 | Cell phone | Communication | Held by char1 | Adds detail | 0,6,25,30 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | An interior space | Neutral | Unknown | Sets the scene |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Atmosphere | Tense due to visible injury | Distressed | Unknown | Adds to the tension |
#
#
# ## Image 17
#
# ### Characters
# | Character ID | Name | Description | Emotions | Actions | Narrative Function | Bounding Box |
# |--------------|------|-------------|----------|---------|-------------------|--------------|
# | char1 | James | Man holding an umbrella | Focused | Enters an elevator | Moves to a different location | 241,38,318,239 |
#
# ### Objects
# | Object ID | Description | Function | Interaction | Narrative Function | Bounding Box |
# |-----------|-------------|----------|------------|-------------------|--------------|
# | obj7 | Elevator | Transportation | Used by char1 | Moves the character | 133,0,396,228 |
# | obj13 | Umbrella | Protection | Held by char1 | Adds detail | 288,87,345,202 |
#
# ### Setting
# | Setting Element | Description | Mood | Time | Narrative Function |
# |-----------------|-------------|------|------|-------------------|
# | Location | Elevator | Neutral | Unknown | Transition |
# | Lighting | Neutral | Unknown | Unknown | Sets the mood |
# | Architecture | Modern elevator interior | Neutral | Unknown | Adds to the setting |
#
#
# ## Narrative Structure
#
# | Narrative Phase | Description | Key Events | Images |
# |-----------------|-------------|-----------|--------|
# | Introduction | James enters the setting | James walks into an empty room and the tension begins | Image 1 |
# | Development | Conflict builds up | James encounters Jack, Alex, and John, and the conflict escalates | Image 2 to Image 12 |
# | Conflict | Confrontation reaches its peak | James and Jack confront each other with guns | Image 13 to Image 14 |
# | Turning Point | Escalation and resolution | James uses a phone, and tension eases slightly | Image 15 to Image 16 |
# | Conclusion | Resolution | James enters an elevator, possibly leaving the scene | Image 17 |

# %% [markdown]
# ## Dataset Pre-Processing

# %%
# IMPORTANT: limit dataset size to avoid RAM crash
small_train_dataset = dataset["train"].select(range(200))
print("Using", len(small_train_dataset), "stories for training")
# Out:
# Using 200 stories for training

# %%
import torch
from torch.utils.data import Dataset
from torchvision import transforms
import re

def clean_story_text(text):
    text = re.sub(r"<.*?>", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


class StoryReasoningDataset(Dataset):
    def __init__(self, hf_dataset, K=4):
        self.dataset = hf_dataset
        self.K = K
        self.transform = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor()
        ])

        # build index map (story_idx, window_start)
        self.index_map = []
        for i, ex in enumerate(self.dataset):
            frame_count = ex["frame_count"]
            for j in range(frame_count - K):
                self.index_map.append((i, j))

    def __len__(self):
        return len(self.index_map)

    def __getitem__(self, idx):
        story_idx, start = self.index_map[idx]
        example = self.dataset[story_idx]

        images = example["images"]
        story_text = clean_story_text(example["story"])

        input_images = images[start:start+self.K]
        target_image = images[start+self.K]

        imgs = [self.transform(img) for img in input_images]
        tgt_img = self.transform(target_image)

        return (
            torch.stack(imgs),     # (K, 3, 224, 224)
            story_text,
            tgt_img,
            story_text
        )

# %%
from torch.utils.data import DataLoader

train_dataset = StoryReasoningDataset(small_train_dataset, K=4)

train_loader = DataLoader(
    train_dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

print("Total training samples:", len(train_dataset))

# Test batch
images, text, tgt_img, tgt_text = next(iter(train_loader))
print("Images:", images.shape)
print("Target image:", tgt_img.shape)
print("Text sample:", text[0][:150])
# Out:
# Total training samples: 1742
# Images: torch.Size([2, 4, 3, 224, 224])
# Target image: torch.Size([2, 3, 224, 224])
# Text sample: In the heart of a dense forest, the man in the blue shirt and the man in the white shirt ran desperately, their hearts pounding with fear. The man in
